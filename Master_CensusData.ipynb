# %% [markdown]
# # NYU - ML4C
# ## Brief
# This notebook
# - imports the shapefile
# - imports census data
# - merges shapefiles with census data
# - map median rent
# - outputs a .csv of the results
# - You can refer to https://github.com/mv1742/ML4C

# %%
#! pip install geopandas
#import all the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.metrics import confusion_matrix
from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn import preprocessing
# %pylab inline

# To ignore some warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

import os
import requests
import shapely
import json
from fiona.crs import from_epsg
import scipy as sp
from scipy import stats
import geopy.distance
#from getCitiBikeCSV import getCitiBikeCSV # must have this function locally or in path
#pd.options.display.max_columns = None
DEVELOPING = False
#from get_jsonparsed_data import get_jsonparsed_data # must have this function locally or in path
#from evalChisq import evalChisqgeoid

from urllib.error import HTTPError
import urllib.request as request
try:
    from urllib import urlretrieve as urlretrieve
except ImportError:
    from urllib.request import urlretrieve as urlretrieve
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import geopandas as gpd
import pylab as pl
import io
import pylab as pl

from geopandas import GeoDataFrame
from geopandas.tools import sjoin
try:
    import ipywidgets as widgets
    hasWidgets = True
except ImportError:
    hasWidgets = False
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# create the directory for shapefiles and set the environmental variable to it

masterdata = os.getenv("Master")
if masterdata is None:
    os.environ["Master"] = "{}/ML4C/Project".format(os.getenv("HOME"))
    masterdata = os.getenv("Master")
    print("Warning: Master environmental variable not found and set by code, please review!")
print("Master: {}".format(masterdata))
# Out:
# Warning: Master environmental variable not found and set by code, please review!
# Master: /nfshome/mv1742/Capstone/udpny_2

# %%
def getGeoDataFrameFromShpFileZipUrl(url):
    '''
    This function downloads the zip file, unzips it into the dorectory 
    pointed to by PUIdata environment variable. Then it 
    reads it into a gepandas dataframe
    '''
    
    folderName = 'shape'+ \
        str(len(os.listdir(os.getenv('Master')))+1)
    os.makedirs(os.getenv('Master') + '/' + folderName)
    urlretrieve(url, "region.zip")
    os.system('unzip -d $Master'+'/'+folderName+' region.zip')
    filenames = [f for f in os.listdir(os.getenv('Master') + '/' + folderName) if f.endswith('.shp') ]
    shapeFile = filenames[0]
    shapeFilePath = os.getenv('Master') + '/' + folderName + '/' + shapeFile
    return gpd.GeoDataFrame.from_file(shapeFilePath)

# %% [markdown]
# # Import Shape Files
# #### Retrieved from latest Census 2016 results from NYC Planning Metro Region Explorer:
# https://metroexplorer.planning.nyc.gov/about
#
# and four missing census tracts from census.gov American Fact Finder: https://factfinder.census.gov/faces/nav/jsf/pages/index.xhtml

# %%
url = 'https://planninglabs.carto.com/api/v2/sql?filename=region&q=SELECT%20%2A%20FROM%20region_censustract_v0&format=SHP'
NYCzip = getGeoDataFrameFromShpFileZipUrl(url)
# NYCzip=gpd.read_file('Censustracts/region.shp')

# %%
NYCzip.plot()

# %%
NYCzip.columns
# Out:
# Index(['aland_mi', 'objectid', 'statefp', 'countyfp', 'tractce', 'geoid',
#        'name', 'namelsad', 'mtfcc', 'funcstat', 'aland', 'awater', 'intptlat',
#        'intptlon', 'shape_leng', 'shape_area', 'atotal', 'atotal_mi',
#        'cartodb_id', 'geoid_1', 'hou16', 'hou16moe', 'hou16cv', 'houv16',
#        'houv16moe', 'houv16cv', 'houo16', 'houo16moe', 'houo16cv', 'hour16',
#        'hour16moe', 'hour16cv', 'emtot15', 'empr15', 'emoff15', 'emins15',
#        'emind15', 'emser15', 'emoth15', 'geometry'],
#       dtype='object')

# %%
NYCzip
# Out:
#       aland_mi  objectid statefp countyfp tractce        geoid     name  \
# 0     10.14335        17      34      013  021601  34013021601   216.01
# 1      3.16034        27      34      003  031100  34003031100      311
# 2      1.84139        50      34      003  036200  34003036200      362
# 3      0.03451        95      34      017  003500  34017003500       35
# 4      0.11672       108      34      017  015500  34017015500      155
# 5      0.12662       130      34      013  013200  34013013200      132
# 6      3.58591       203      34      027  044501  34027044501   445.01
# 7      1.32701       209      34      023  004500  34023004500       45
# 8      1.36273       225      34      003  007001  34003007001    70.01
# 9      0.31952       237      34      003  019102  34003019102   191.02
# 10    19.60247       288      34      025  812502  34025812502  8125.02
# 11     5.16034       337      34      035  053604  34035053604   536.04
# 12     0.12785       353      34      003  006202  34003006202    62.02
# 13     3.40749       382      34      023  006203  34023006203    62.03
# 14     1.93816       385      34      027  041706  34027041706   417.06
# 15     0.14459       405      34      031  175801  34031175801  1758.01
# 16     0.54219       423      34      023  001300  34023001300       13
# 17     2.62672       549      34      003  042400  34003042400      424
# 18     7.55029       557      34      035  052201  34035052201   522.01
# 19     2.15177       656      34      029  722600  34029722600     7226
# 20     0.22944       660      34      013  012400  34013012400      124
# 21     1.90085       671      34      017  005802  34017005802    58.02
# 22     3.66477       692      34      029  738100  34029738100     7381
# 23     8.22750       707      34      021  004304  34021004304    43.04
# 24     3.31140       708      34      021  003202  34021003202    32.02
# 25     9.78031       710      34      021  003302  34021003302    33.02
# 26     6.04303       782      34      035  052400  34035052400      524
# 27     0.41189       797      34      025  801700  34025801700     8017
# 28     1.54133       805      34      025  803900  34025803900     8039
# 29     2.71226       819      34      025  804200  34025804200     8042
# ...        ...       ...     ...      ...     ...          ...      ...
# 5264   0.97014      5250      36      119  014400  36119014400      144
# 5265   0.43802      5251      36      059  981100  36059981100     9811
# 5266   0.22853      5253      36      059  416401  36059416401  4164.01
# 5267   0.22905      5254      36      059  416402  36059416402  4164.02
# 5268   0.19062      5255      36      059  416801  36059416801  4168.01
# 5269   0.10503      5260      36      061  016200  36061016200      162
# 5270   0.06727      5261      36      061  016600  36061016600      166
# 5271   0.07605      5262      36      061  016700  36061016700      167
# 5272   0.07694      5263      36      061  016800  36061016800      168
# 5273   0.07062      5264      36      061  017000  36061017000      170
# 5274   0.08411      5265      36      061  017100  36061017100      171
# 5275   0.07330      5278      36      061  019200  36061019200      192
# 5276   0.09608      5270      36      061  017800  36061017800      178
# 5277   0.05346      5271      36      061  018100  36061018100      181
# 5278   0.06830      5272      36      061  018200  36061018200      182
# 5279   0.08661      5273      36      061  018300  36061018300      183
# 5280   0.06818      5274      36      061  018400  36061018400      184
# 5281   0.05034      5275      36      061  018500  36061018500      185
# 5282   0.04700      5276      36      061  018600  36061018600      186
# 5283   0.05735      5277      36      061  018800  36061018800      188
# 5284   0.06881      5287      36      061  020300  36061020300      203
# 5285   0.07866      5291      36      061  021000  36061021000      210
# 5286   0.13436      5292      36      061  021100  36061021100      211
# 5287   0.06811      5293      36      061  021200  36061021200      212
# 5288   0.05234      5294      36      061  021400  36061021400      214
# 5289   0.12118      5295      36      061  021703  36061021703   217.03
# 5290   0.07022      5296      36      061  021800  36061021800      218
# 5291   0.10788      5297      36      061  021900  36061021900      219
# 5292   0.03822      5298      36      061  022102  36061022102   221.02
# 5293   0.15057      5305      36      047  152200  36047152200     1522
#
#                   namelsad  mtfcc funcstat  \
# 0      Census Tract 216.01  G5020        S
# 1         Census Tract 311  G5020        S
# 2         Census Tract 362  G5020        S
# 3          Census Tract 35  G5020        S
# 4         Census Tract 155  G5020        S
# 5         Census Tract 132  G5020        S
# 6      Census Tract 445.01  G5020        S
# 7          Census Tract 45  G5020        S
# 8       Census Tract 70.01  G5020        S
# 9      Census Tract 191.02  G5020        S
# 10    Census Tract 8125.02  G5020        S
# 11     Census Tract 536.04  G5020        S
# 12      Census Tract 62.02  G5020        S
# 13      Census Tract 62.03  G5020        S
# 14     Census Tract 417.06  G5020        S
# 15    Census Tract 1758.01  G5020        S
# 16         Census Tract 13  G5020        S
# 17        Census Tract 424  G5020        S
# 18     Census Tract 522.01  G5020        S
# 19       Census Tract 7226  G5020        S
# 20        Census Tract 124  G5020        S
# 21      Census Tract 58.02  G5020        S
# 22       Census Tract 7381  G5020        S
# 23      Census Tract 43.04  G5020        S
# 24      Census Tract 32.02  G5020        S
# 25      Census Tract 33.02  G5020        S
# 26        Census Tract 524  G5020        S
# 27       Census Tract 8017  G5020        S
# 28       Census Tract 8039  G5020        S
# 29       Census Tract 8042  G5020        S
# ...                    ...    ...      ...
# 5264      Census Tract 144  G5020        S
# 5265     Census Tract 9811  G5020        S
# 5266  Census Tract 4164.01  G5020        S
# 5267  Census Tract 4164.02  G5020        S
# 5268  Census Tract 4168.01  G5020        S
# 5269      Census Tract 162  G5020        S
# 5270      Census Tract 166  G5020        S
# 5271      Census Tract 167  G5020        S
# 5272      Census Tract 168  G5020        S
# 5273      Census Tract 170  G5020        S
# 5274      Census Tract 171  G5020        S
# 5275      Census Tract 192  G5020        S
# 5276      Census Tract 178  G5020        S
# 5277      Census Tract 181  G5020        S
# 5278      Census Tract 182  G5020        S
# 5279      Census Tract 183  G5020        S
# 5280      Census Tract 184  G5020        S
# 5281      Census Tract 185  G5020        S
# 5282      Census Tract 186  G5020        S
# 5283      Census Tract 188  G5020        S
# 5284      Census Tract 203  G5020        S
# 5285      Census Tract 210  G5020        S
# 5286      Census Tract 211  G5020        S
# 5287      Census Tract 212  G5020        S
# 5288      Census Tract 214  G5020        S
# 5289   Census Tract 217.03  G5020        S
# 5290      Census Tract 218  G5020        S
# 5291      Census Tract 219  G5020        S
# 5292   Census Tract 221.02  G5020        S
# 5293     Census Tract 1522  G5020        S
#
#                             ...                          hour16moe   hour16cv  \
# 0                           ...                              109.0  25.583551
# 1                           ...                              214.0  10.602379
# 2                           ...                               75.0  19.156599
# 3                           ...                               67.0   6.133958
# 4                           ...                              137.0   6.123726
# 5                           ...                              127.0  11.804839
# 6                           ...                              147.0  12.693424
# 7                           ...                              144.0   4.937281
# 8                           ...                               81.0  16.468268
# 9                           ...                               88.0   7.471430
# 10                          ...                               48.0  32.785766
# 11                          ...                               58.0  27.121814
# 12                          ...                              199.0  18.469106
# 13                          ...                              204.0   8.720968
# 14                          ...                              157.0   4.597338
# 15                          ...                               82.0   4.129911
# 16                          ...                              100.0   7.359597
# 17                          ...                               33.0  44.579534
# 18                          ...                               90.0  20.338753
# 19                          ...                               57.0  39.375518
# 20                          ...                              155.0   6.498271
# 21                          ...                               58.0  14.047155
# 22                          ...                               22.0  31.102000
# 23                          ...                               92.0  25.892154
# 24                          ...                              125.0  12.457023
# 25                          ...                              242.0  11.703458
# 26                          ...                               75.0  11.229730
# 27                          ...                              192.0  12.286034
# 28                          ...                               78.0  24.825347
# 29                          ...                               82.0  34.377948
# ...                         ...                                ...        ...
# 5264                        ...                              139.0   8.783626
# 5265                        ...                               11.0   0.000000
# 5266                        ...                              133.0   9.800129
# 5267                        ...                              100.0  15.159669
# 5268                        ...                               38.0  51.334009
# 5269                        ...                              217.0   3.749713
# 5270                        ...                              161.0   3.565477
# 5271                        ...                              199.0   6.366981
# 5272                        ...                               82.0   3.037661
# 5273                        ...                              151.0   2.904852
# 5274                        ...                              289.0   6.344669
# 5275                        ...                               58.0   2.656998
# 5276                        ...                              125.0   4.889823
# 5277                        ...                              321.0   5.620299
# 5278                        ...                              131.0   2.922395
# 5279                        ...                              339.0   7.565309
# 5280                        ...                              203.0   4.634031
# 5281                        ...                              190.0   5.681334
# 5282                        ...                              108.0   3.250173
# 5283                        ...                              191.0   5.420608
# 5284                        ...                               61.0  10.655766
# 5285                        ...                              180.0   3.914937
# 5286                        ...                              311.0   6.387086
# 5287                        ...                              141.0   3.452045
# 5288                        ...                              102.0   3.333660
# 5289                        ...                               11.0   0.000000
# 5290                        ...                              151.0   3.566174
# 5291                        ...                              134.0   4.022665
# 5292                        ...                              117.0   8.397240
# 5293                        ...                               85.0  12.016682
#
#       emtot15   empr15  emoff15  emins15  emind15  emser15  emoth15  \
# 0     22750.0  22492.0   7641.0   1229.0  10729.0   2162.0    731.0
# 1      8274.0   8172.0   3602.0    219.0   3181.0   1084.0     86.0
# 2      8825.0   8224.0   1252.0    217.0   5718.0    975.0     62.0
# 3        58.0     58.0     33.0      7.0      4.0     14.0      0.0
# 4       676.0    620.0     82.0    106.0     84.0    321.0     27.0
# 5        93.0     93.0     11.0      2.0      6.0     65.0      9.0
# 6      3505.0   3185.0    683.0     48.0    195.0   2134.0    125.0
# 7       718.0    718.0    171.0      2.0    492.0     41.0     12.0
# 8      1115.0   1114.0    194.0    292.0    376.0    206.0     46.0
# 9      1707.0   1549.0    706.0    478.0    212.0    118.0     35.0
# 10     1144.0   1099.0    399.0     78.0    365.0    137.0    120.0
# 11     6431.0   6167.0   1209.0   1001.0   2942.0    887.0    128.0
# 12      396.0    396.0     99.0     77.0     44.0    122.0     54.0
# 13     4393.0   2758.0    423.0    148.0    867.0   1226.0     94.0
# 14     1979.0   1977.0   1539.0     49.0    111.0    234.0     44.0
# 15     1477.0    806.0    377.0    256.0     30.0    108.0     35.0
# 16      882.0    569.0     60.0    141.0     49.0    263.0     56.0
# 17     9806.0   7462.0   2262.0   1217.0    992.0   2897.0     94.0
# 18     4547.0   3896.0   1816.0    650.0    715.0    524.0    191.0
# 19      681.0    681.0     55.0     64.0     26.0    479.0     57.0
# 20      234.0    107.0     29.0      9.0      6.0     63.0      0.0
# 21     3527.0   3511.0    297.0     15.0   2210.0    987.0      2.0
# 22      328.0    307.0     95.0     10.0     95.0     90.0     17.0
# 23     1370.0   1370.0    426.0    243.0    116.0    480.0    105.0
# 24     5553.0   5476.0   1122.0   2489.0    323.0   1384.0    158.0
# 25     8048.0   8043.0   3157.0    569.0   1119.0   3039.0    159.0
# 26     9546.0   8113.0   6883.0    373.0    117.0    693.0     47.0
# 27      402.0    342.0      9.0    282.0      9.0     37.0      5.0
# 28     1180.0    722.0    179.0     74.0     61.0    383.0     25.0
# 29     2270.0   1784.0    353.0    395.0    202.0    753.0     81.0
# ...       ...      ...      ...      ...      ...      ...      ...
# 5264    737.0    667.0    276.0    187.0     30.0    119.0     55.0
# 5265   2600.0   2585.0     11.0   2392.0     35.0    146.0      1.0
# 5266    471.0    363.0     60.0     41.0     26.0    215.0     21.0
# 5267    941.0    561.0     77.0    407.0     29.0     30.0     18.0
# 5268    277.0    167.0     23.0     24.0     32.0     81.0      7.0
# 5269    897.0    742.0    241.0    390.0     35.0     59.0     17.0
# 5270   2005.0   1059.0    178.0    188.0    334.0    351.0      8.0
# 5271   2686.0   2685.0    498.0    550.0     42.0   1274.0    321.0
# 5272  19142.0  18933.0     49.0  18012.0      5.0    480.0    387.0
# 5273   1476.0   1181.0    201.0    552.0     18.0    322.0     88.0
# 5274   3845.0   3845.0    633.0   1550.0     68.0   1292.0    302.0
# 5275    331.0    165.0     19.0     33.0      0.0     63.0     50.0
# 5276   1288.0   1031.0    126.0     87.0     52.0    754.0     12.0
# 5277   1487.0   1482.0    208.0    818.0      2.0    277.0    177.0
# 5278   1476.0    699.0     89.0    140.0    124.0    265.0     81.0
# 5279   1686.0   1686.0    366.0    141.0     53.0    980.0    146.0
# 5280    515.0    431.0     19.0    274.0     14.0     93.0     31.0
# 5281   1522.0   1522.0    169.0    241.0     21.0   1017.0     74.0
# 5282    430.0    238.0     29.0    182.0      1.0     10.0     16.0
# 5283    909.0    827.0     72.0    310.0    111.0    301.0     33.0
# 5284  29649.0  29480.0    109.0  29240.0     40.0     76.0     15.0
# 5285    149.0    148.0     71.0     65.0      1.0      9.0      2.0
# 5286   1968.0   1966.0    161.0   1209.0     67.0    498.0     31.0
# 5287   3835.0   1135.0     81.0    725.0      0.0    302.0     27.0
# 5288    320.0    320.0     51.0    207.0      0.0     58.0      4.0
# 5289   1510.0   1147.0    854.0    248.0      6.0      9.0     30.0
# 5290   1179.0    931.0    120.0    241.0     85.0    405.0     80.0
# 5291   3390.0   2493.0    211.0    232.0    260.0   1534.0    256.0
# 5292    412.0    180.0     47.0     99.0      3.0     15.0     16.0
# 5293    499.0    498.0     64.0    168.0     38.0    202.0     26.0
#
#                                                geometry
# 0     POLYGON ((-74.3228040001045 40.90883400018899,...
# 1     POLYGON ((-74.08304199968846 40.78623200040653...
# 2     POLYGON ((-74.03536299980257 40.82861799992076...
# 3     POLYGON ((-74.04668899959766 40.72066899957468...
# 4     POLYGON ((-74.01458600034361 40.79119299985706...
# 5     POLYGON ((-74.21338700040968 40.73388700028482...
# 6     (POLYGON ((-74.56219999983014 40.9012120003335...
# 7     (POLYGON ((-74.25451090392684 40.5403372012258...
# 8     POLYGON ((-73.96304000019583 40.98273799985878...
# 9     POLYGON ((-73.95468099962847 40.8616329998631,...
# 10    POLYGON ((-74.41671499969745 40.16536199965662...
# 11    POLYGON ((-74.66720900039509 40.61590999974675...
# 12    POLYGON ((-73.97682500007369 40.82783299969318...
# 13    POLYGON ((-74.47185199996979 40.44337200031759...
# 14    POLYGON ((-74.37497500029599 40.89193299960826...
# 15    POLYGON ((-74.12043500007513 40.85413000009949...
# 16    POLYGON ((-74.41806599994592 40.49137799999475...
# 17    POLYGON ((-74.07207000003049 40.94865900031262...
# 18    POLYGON ((-74.44869000024333 40.65523100001066...
# 19    (POLYGON ((-74.15031499694514 39.9957130046421...
# 20    POLYGON ((-74.22998499960802 40.72519899983403...
# 21    POLYGON ((-74.06878399958187 40.70096099995016...
# 22    POLYGON ((-74.15706565722054 39.66940797912223...
# 23    POLYGON ((-74.57339699997154 40.30089999973519...
# 24    POLYGON ((-74.69171700013946 40.26829499981442...
# 25    POLYGON ((-74.70642000008297 40.34599900025372...
# 26    POLYGON ((-74.54900500018061 40.74093499975048...
# 27    (POLYGON ((-74.19838800030597 40.4395070001479...
# 28    (POLYGON ((-73.99465699289391 40.3776559991386...
# 29    POLYGON ((-74.02655791928737 40.33947506740999...
# ...                                                 ...
# 5264  POLYGON ((-73.89574300033918 41.29385300011587...
# 5265  POLYGON ((-73.60149399994815 40.81937600000241...
# 5266  POLYGON ((-73.69029500041397 40.58880603213396...
# 5267  POLYGON ((-73.68128600044855 40.58838800040589...
# 5268  POLYGON ((-73.63746478294019 40.59511384926169...
# 5269  (POLYGON ((-73.93275567343714 40.7779632059886...
# 5270  POLYGON ((-73.94516799980335 40.7908939995585,...
# 5271  POLYGON ((-73.97690200002721 40.78509800027255...
# 5272  POLYGON ((-73.94789599970061 40.79292799982733...
# 5273  POLYGON ((-73.93864899955173 40.79155799960207...
# 5274  POLYGON ((-73.97501600028815 40.78768700005503...
# 5275  (POLYGON ((-73.92696300024225 40.7952420004180...
# 5276  (POLYGON ((-73.93171837313743 40.7902700022167...
# 5277  POLYGON ((-73.96417600042207 40.79236199980644...
# 5278  POLYGON ((-73.93860300012834 40.79988300040021...
# 5279  POLYGON ((-73.9694150001021 40.79536099961048,...
# 5280  POLYGON ((-73.94182500032352 40.80124000002603...
# 5281  POLYGON ((-73.96283399968931 40.79420300016837...
# 5282  POLYGON ((-73.94697400034978 40.79996100039983...
# 5283  POLYGON ((-73.93399099968484 40.79793200036153...
# 5284  POLYGON ((-73.95827199975292 40.81062900042808...
# 5285  (POLYGON ((-73.93260499962105 40.8115170000095...
# 5286  POLYGON ((-73.95626900001432 40.81337500025604...
# 5287  POLYGON ((-73.93575600013925 40.81532600029464...
# 5288  POLYGON ((-73.93447500042095 40.81969700041622...
# 5289  POLYGON ((-73.94607800039937 40.82126399983373...
# 5290  POLYGON ((-73.94872800029694 40.80333100022552...
# 5291  POLYGON ((-73.9554510000636 40.81937700004859,...
# 5292  POLYGON ((-73.94515500010318 40.82087599992749...
# 5293  POLYGON ((-73.96408699991511 40.6444069999831,...
#
# [5294 rows x 40 columns]

# %%
NYCzip.rename(columns={"geoid": "GEOID"},inplace=True)
NYCzip.GEOID = NYCzip.GEOID.astype(int)
cols = ['GEOID','geometry']
NYCzip = NYCzip.loc[:,cols]
#NYCzipgdp.plot(column='GEOID',legend = True)
NYCzip.shape
# Out:
# (5294, 2)

# %%
NYCzip.isnull().sum()
# Out:
# GEOID       0
# geometry    0
# dtype: int64

# %%
# NYCzipgdp.dropna(inplace=True)
NYCzip.shape
# Out:
# (5294, 2)

# %%
figure, ax = plt.subplots(figsize=(15, 15))
NYCzip.plot(column='GEOID',legend = True, ax=ax)

# %%
(NYCzip.GEOID == 34005701502).sum()
# Out:
# 0

# %% [markdown]
# # Import Latest Census Data

# %%
Censuspd=pd.read_csv('Census_data.csv')
Censuspdgdp = gpd.GeoDataFrame(Censuspd)
Censuspdgdp.columns
# Out:
# Index(['geoid', 'medrent90', 'medrent00', 'medrent16', 'medhval90',
#        'medhval00', 'medhval16', 'percol90', 'percol00', 'percol16',
#        'pernwh90', 'pernwh00', 'pernwh16', 'perli90', 'perli00', 'perli16',
#        'per_rent_90', 'per_rent_00', 'per_rent16', 'pop00', 'pop16',
#        'asian_16_low', 'carcommuters_00', 'pre50_16', 'hhwch16', 'empd15',
#        'density16', 'aland', 'li16', 'afford90', 'belowmedcol90',
#        'abovemednwh', 'abovemedli', 'abovemedrent', 'vulnrisk90', 'vuln90',
#        'afford00', 'belowmedcol00', 'abovemednwh00', 'abovemedli00',
#        'abovemedrent00', 'vulnrisk00', 'vuln00', 'afford16', 'belowmedcol16',
#        'abovemednwh16', 'abovemedli16', 'abovemedrent16', 'vulnrisk16',
#        'vuln16', 'hotmarket90(127%-169%)', 'hotmarket00(110%-207%)',
#        'percol16.1', 'edudiff0016', 'abm_dif_0016', 'edudiff9000',
#        'abm_dif_9000', 'hinc90_NYU', 'hinc00_NYU', 'hinc16_NYU', 'hinc90',
#        'hinc00', 'hinc16', 'pct_ch_hinc90_00', 'pct_ch_hinc00_16',
#        'abm_inc_90_00', 'abm_inc_00_16', 'li16.1', 'gent90_00', 'gent00_16',
#        'ch_all_li_count90_00', 'ch_all_li_count00_16', 'liloss9016',
#        'per_limove16', 'per_limove09', 'exclusion', 'popgrowth0016',
#        'Incch0016', 'li_hh_16'],
#       dtype='object')

# %%
Censuspdgdp.rename(columns={'geoid': "GEOID"},inplace=True)
Censuspdgdp.tail()
# Out:
#              GEOID  medrent90  medrent00  medrent16  medhval90  medhval00  \
# 5293  3.611998e+10        NaN        NaN        NaN        NaN        NaN
# 5294           NaN        NaN        NaN        NaN        NaN        NaN
# 5295           NaN        NaN        NaN        NaN        NaN        NaN
# 5296           NaN      623.0      793.0     1342.0   175600.0   192800.0
# 5297           NaN      498.4      634.4     1073.6   140480.0   154240.0
#
#       medhval16  percol90  percol00  percol16    ...     gent00_16  \
# 5293        NaN   0.00000  0.000000  0.681818    ...           NaN
# 5294        NaN       NaN       NaN       NaN    ...           NaN
# 5295        NaN       NaN       NaN       NaN    ...           NaN
# 5296   400000.0   0.18229  0.163948  0.331415    ...           NaN
# 5297   320000.0       NaN       NaN       NaN    ...           NaN
#
#       ch_all_li_count90_00  ch_all_li_count00_16  liloss9016  per_limove16  \
# 5293                #NULL!           0.721796274      #NULL!        #NULL!
# 5294                   NaN                   NaN         NaN           NaN
# 5295                   NaN                   NaN         NaN           NaN
# 5296                   NaN                   NaN         NaN           NaN
# 5297                   NaN                   NaN         NaN           NaN
#
#       per_limove09  exclusion  popgrowth0016  Incch0016  li_hh_16
# 5293        #NULL!          1            NaN    #DIV/0!       0.0
# 5294           NaN        NaN            NaN        NaN       NaN
# 5295           NaN        NaN            NaN        NaN       NaN
# 5296           NaN        NaN            NaN        NaN       NaN
# 5297           NaN        NaN            NaN        NaN       NaN
#
# [5 rows x 79 columns]

# %%
cols_typ = ['GEOID','medrent16']
print(type(Censuspdgdp.iloc[:,0][0]))
#Typologies.rename(columns={'\ufeffgeoid': "GEOID"},inplace=True)
#Typologiesgdp.geoid = Typologies.iloc[:,0]
Censuspdgdp = Censuspdgdp.loc[:,cols_typ]
Censuspdgdp.head()
# Out:
# <class 'numpy.float64'>
#           GEOID  medrent16
# 0  9.001010e+09     1510.0
# 1  9.001010e+09     1628.0
# 2  9.001010e+09     2113.0
# 3  9.001010e+09     2250.0
# 4  9.001010e+09     1900.0

# %%
Censuspdgdp.shape
# Out:
# (5298, 2)

# %%
Censuspdgdp.dropna(inplace=True)
Censuspdgdp.GEOID = Censuspdgdp.GEOID.astype(int)

# %% [markdown]
# ## Clean Data

# %% [markdown]
# ## Clean Typologies

# %%
#NYCzipgdp.isnull().sum()
Censuspdgdp.isin([0]).sum()
# Out:
# GEOID         0
# medrent16    72
# dtype: int64

# %%
Censuspdgdp.isnull().sum()
# Out:
# GEOID        0
# medrent16    0
# dtype: int64

# %%
print(len(Censuspdgdp.GEOID.unique()))
Censuspdgdp.dropna(inplace=True)
Censuspdgdp.shape
# Out:
# 5134
# (5134, 2)

# %%
Censuspdgdp =Censuspdgdp.drop_duplicates()
Censuspdgdp.shape
# Out:
# (5134, 2)

# %%
# print(NYCzipgdp.shape)
Censuspdgdp.rename(columns={'geoid': "GEOID"},inplace=True)
Censuspdgdp[Censuspdgdp.GEOID==36047021000]
# Out:
#             GEOID  medrent16
# 2574  36047021000     1294.0

# %%
Censuspdgdp.tail()
# Out:
#             GEOID  medrent16
# 5287  36119014909     2194.0
# 5288  36119015000     1705.0
# 5289  36119981000      994.0
# 5291  36119983000        0.0
# 5292  36119984000     1193.0

# %% [markdown]
# ### MERGE

# %%
merged = NYCzip.merge(Censuspdgdp,on='GEOID')
merged.tail()
# Out:
#             GEOID                                           geometry  \
# 5127  36061021703  POLYGON ((-73.94607800039937 40.82126399983373...
# 5128  36061021800  POLYGON ((-73.94872800029694 40.80333100022552...
# 5129  36061021900  POLYGON ((-73.9554510000636 40.81937700004859,...
# 5130  36061022102  POLYGON ((-73.94515500010318 40.82087599992749...
# 5131  36047152200  POLYGON ((-73.96408699991511 40.6444069999831,...
#
#       medrent16
# 5127        0.0
# 5128     1184.0
# 5129      528.0
# 5130     1196.0
# 5131     1532.0

# %%
print(type(merged),merged.shape)
mergedgpd = gpd.GeoDataFrame(merged)
mergedgpd.shape
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'> (5132, 3)
# (5132, 3)

# %%
mergedgpd.isnull().sum()
# Out:
# GEOID        0
# geometry     0
# medrent16    0
# dtype: int64

# %%
print(len(Censuspdgdp.GEOID),len(mergedgpd.GEOID))
print(type(Censuspdgdp.GEOID),type(mergedgpd.GEOID))
# Out:
# 5134 5132
# <class 'pandas.core.series.Series'> <class 'pandas.core.series.Series'>

# %%
excluded = []
for i in Censuspdgdp.GEOID:
    if i not in list(mergedgpd.GEOID):
        print('i',i)
        excluded.append(i)
excluded
# Out:
# i 34005701502
# i 34005701700
# [34005701502, 34005701700]

# %%
(NYCzip.GEOID == 36061022102).sum()
# Out:
# 1

# %%
# mergedgpd.crs = from_epsg(4326)
# mergedgpd.crs

# %%
# mergedgpd.to_crs(epsg=2263, inplace = True)
# mergedgpd.crs

# %%
figure, ax = plt.subplots(figsize=(15, 15))
mergedgpd.plot(column='medrent16',legend = True, ax=ax)

# %%
# mergedgpd.to_csv('UDPNY_shapefilesTypology_final_1.19.19.csv')

# %%
figure, ax = plt.subplots(figsize=(5, 5))
mergedgpd.plot(column='GEOID',legend = True, ax=ax)

# %%
figure, ax = plt.subplots(figsize=(5, 5))
NYCzip.plot(column='GEOID',legend = True, ax=ax)
